# %%
p, q, r, s = 4, 7, 2, 4

import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from scipy.stats import iqr
from sklearn import datasets
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from pprint import pprint
plt.style.use('ggplot')
#from skgstat import Variogram, OrdinaryKriging
from sklearn import decomposition
from sklearn import datasets

#pair wise plot using seaborn

# %%
iris = pd.read_csv(r'C:\Users\rhall35\Downloads\iris.csv')
iris.drop('Id', inplace=True, axis=1)
iris.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# A: Exploratory Data Analytics (10):
# <br/>Perform exploratory data analysis for “Iris.csv”. Report the relevant statistics such as mean,
# variances, IQR, box plots and cross-variograms.

# %%
print(iris.info())

#Assumptions: no missing data, all columns are float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# None

# %%
print(iris.shape)

print(iris.columns)

print(iris['Species'].value_counts())
# Out:
# (150, 5)
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
print(iris.describe())
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
for ojha, feature in enumerate(list(iris.columns)[:-1]):
    fg = sns.FacetGrid(iris, hue='Species', height=5)
    fg.map(sns.distplot, feature).add_legend()
    plt.show()

# %%
sns.boxplot(data=iris)
plt.show()

# %%
var = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

fig, ax = plt.subplots(2,2, figsize=(14,6))
for var, subplot in zip(var, ax.flatten()):
    sns.boxplot(x='Species', y=var, data=iris, ax=subplot)
    sns.swarmplot(x='Species', y=var, data=iris, ax=subplot)
fig.tight_layout()
plt.show()

# %%
#Sepal Length IQR
SL_q1 = iris['SepalLengthCm'].quantile(.25)
SL_q3 = iris['SepalLengthCm'].quantile(.75)
SL_iqr = SL_q3 - SL_q1
print('Sepal Length IQR:', SL_iqr)

#Sepal Width IQR
SW_q1 = iris['SepalWidthCm'].quantile(.25)
SW_q3 = iris['SepalWidthCm'].quantile(.75)
SW_iqr = SW_q3 - SW_q1
print('Sepal Width IQR:', SW_iqr)

#Petal Length IQR
PL_q1 = iris['PetalLengthCm'].quantile(.25)
PL_q3 = iris['PetalLengthCm'].quantile(.75)
PL_iqr = PL_q3 - PL_q1
print('Petal Length IQR:', PL_iqr)

#Petal Width IQR
PW_q1 = iris['PetalWidthCm'].quantile(.25)
PW_q3 = iris['PetalWidthCm'].quantile(.75)
PW_iqr = PW_q3 - PW_q1
print('Petal Width IQR:', PW_iqr)
# Out:
# Sepal Length IQR: 1.3000000000000007
# Sepal Width IQR: 0.5
# Petal Length IQR: 3.4999999999999996
# Petal Width IQR: 1.5

# %%
sns.set(style='ticks', color_codes=True)
g = sns.pairplot(iris)
plt.show()

# %% [markdown]
# B: Dimension Reduction (20):
# <br/>Perform dimension reduction using Principal Component Analysis (PCA) on “Iris.csv”. Justify
# the selection of reduced dimensions in terms of explained variance and report the selected
# principal components in terms of original dimensions.

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA

X = iris.iloc[:, 0:4]
y = iris.iloc[:,-1]

scaler = preprocessing.StandardScaler()

scaler.fit(X)
X_scaled_array = scaler.transform(X)
X_scaled = pd.DataFrame(X_scaled_array, columns = X.columns)

ndimensions = 2
seed = 0

pca = PCA(n_components=ndimensions, random_state=seed)
pca.fit(X_scaled)
X_pca_array = pca.transform(X_scaled)
X_pca = pd.DataFrame(X_pca_array, columns=['PC1','PC2'])

y_id_array = pd.Categorical(iris['Species']).codes

df_plot = X_pca.copy()
df_plot['ClusterKmeans'] = y_cluster_kmeans
df_plot['SpeciesId'] = y_id_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-3af2337b9312> in <module>
#      22
#      23 df_plot = X_pca.copy()
# ---> 24 df_plot['ClusterKmeans'] = y_cluster_kmeans
#      25 df_plot['SpeciesId'] = y_id_array
#
# NameError: name 'y_cluster_kmeans' is not defined

# %%
#from lecture 

print(__doc__)

np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]
iris = datasets.load_iris()
X = iris.data
y = iris.target

fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()
pca = decomposition.PCA(n_components=4)
pca.fit(X)
X = pca.transform(X)

for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
    
y = np.choose(y, [1, 2, 0]).astype(float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
pca_comp = pca.components_
pca_var = pca.explained_variance_
print('Explained Variance:', pca_var)
print('Principal Components:', pca_comp)
# Out:
# Explained Variance: [4.22824171 0.24267075 0.0782095  0.02383509]
# Principal Components: [[ 0.36138659 -0.08452251  0.85667061  0.3582892 ]
#  [ 0.65658877  0.73016143 -0.17337266 -0.07548102]
#  [-0.58202985  0.59791083  0.07623608  0.54583143]
#  [-0.31548719  0.3197231   0.47983899 -0.75365743]]

# %%
print(pca_comp)
# Out:
# [[ 0.36138659 -0.08452251  0.85667061  0.3582892 ]
#  [ 0.65658877  0.73016143 -0.17337266 -0.07548102]
#  [-0.58202985  0.59791083  0.07623608  0.54583143]
#  [-0.31548719  0.3197231   0.47983899 -0.75365743]]

# %% [markdown]
# C: Unsupervised Learning (30):
# <br/>Carry out a K-Means clustering analysis for “Iris.csv”. Report three clustering results with initial
# guesses using last four-digits of student-ID [p,q,r,s] as shown in the following:
#     <br/>       i) 2 Clusters: Initial guess = [Mean(PC1) + p/10, Mean(PC2) + q/10];
#     <br/>ii) 3 Clusters: Initial guess = [Mean(PC1) + p/10, Mean(PC2) + q/10, Mean(PC3) + r/10]
#     <br/>iii) 4 Clusters: Initial guess = [Mean(PC1) + p/10, Mean(PC2) + q/10, Mean(PC3) + r/10,
# Mean(PC4) + s/10]

# %%
print(__doc__)

# Code source: Gaël Varoquaux
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
# Though the following import is not directly being used, it is required
# for 3D projection to work
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import KMeans
from sklearn import datasets

np.random.seed(5)

iris = datasets.load_iris()
X = iris.data
y = iris.target
# Out:
# Automatically created module for IPython interactive environment

# %%
#i

estimators = [('k_means_iris_2', KMeans(n_clusters=2,init=pca_comp[:2])),
              ('k_means_iris_2', KMeans(n_clusters=3, init=pca_comp[:3])),
              ('k_means_iris_2', KMeans(n_clusters=4, init=pca_comp[:4]))]

fignum = 1
titles = ['2 clusters', '3 clusters', '4 clusters']
for name, est in estimators:
    fig = plt.figure(fignum, figsize=(4, 3))
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
    est.fit(X)
    labels = est.labels_

    ax.scatter(X[:, 3], X[:, 0], X[:, 2],
               c=labels.astype(float), edgecolor='k')

    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_xlabel('Petal width')
    ax.set_ylabel('Sepal length')
    ax.set_zlabel('Petal length')
    ax.set_title(titles[fignum - 1])
    ax.dist = 12
    fignum = fignum + 1

# Plot the ground truth
fig = plt.figure(fignum, figsize=(4, 3))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

for name, label in [('Setosa', 0),
                    ('Versicolour', 1),
                    ('Virginica', 2)]:
    ax.text3D(X[y == label, 3].mean(),
              X[y == label, 0].mean(),
              X[y == label, 2].mean() + 2, name,
              horizontalalignment='center',
              bbox=dict(alpha=.2, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y.astype(int), [1, 2, 0])
ax.scatter(X[:, 3], X[:, 0], X[:, 2], c=y, edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_xlabel('Petal width')
ax.set_ylabel('Sepal length')
ax.set_zlabel('Petal length')
ax.set_title('Ground Truth')
ax.dist = 12

fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# D: Supervised Learning (40):
# <br/>Calculate s%2+1 and select 1. For RF and 2. For SVM
# <br/>Build a supervised learning model using 1. Random Forest (RF) or 2. Support Vector Machine
# (SVM)for classification of Iris species. Report all the steps in building the supervised learning
# model by splitting into “Training” datasets, performing cross-validation, and construct the
# confusion matrix on “Test” data. Summarize the results of overall data analytics and machine
# learning framework.

# %%
number = s%2 + 1
if number == 1:
    print("Random Forest")
else:
    print('Support Vector Machine')
    
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

#used https://chrisalbon.com/machine_learning/trees_and_forests/random_forest_classifier_example/
# Out:
# Random Forest

# %%
np.random.seed(0)

df = pd.DataFrame(iris.data, columns=iris.feature_names)

df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %%
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %%
df['is_train'] = np.random.uniform(0, 1, len(df)) <= .75


df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %%
train, test = df[df['is_train']==True], df[df['is_train']==False]

print('Number of observations in the training data:', len(train))
print('Number of observations in the test data:',len(test))
# Out:
# Number of observations in the training data: 118
# Number of observations in the test data: 32

# %%
features = df.columns[:4]

features
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
y = pd.factorize(train['species'])[0]

clf = RandomForestClassifier(n_jobs=2, random_state=0)
clf.fit(train[features], y)

clf.predict(test[features])

clf.predict_proba(test[features])[0:10]

preds = iris.target_names[clf.predict(test[features])]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
pd.crosstab(test['species'], preds, rownames=['Actual Species'], colnames=['Predicted Species'])
# Out:
# Predicted Species  setosa  versicolor  virginica
# Actual Species
# setosa                 13           0          0
# versicolor              0           5          2
# virginica               0           0         12

# %%
list(zip(train[features], clf.feature_importances_))
# Out:
# [('sepal length (cm)', 0.11185992930506346),
#  ('sepal width (cm)', 0.016341813006098178),
#  ('petal length (cm)', 0.36439533040889194),
#  ('petal width (cm)', 0.5074029272799464)]
